# %%
import json
from pathlib import Path
import numpy as np
from matplotlib import pyplot as plt

# %%
# %cd ..
# Out:
# /home/s-uesaka/hard-prompts-made-easy

# %%
with open(Path("hard_prompts_xgaze.json"), 'r') as f:
    hard_prompts = json.load(f)

# %%
len(hard_prompts)
# Out:
# 80

# %%
similarities = [hard_prompt['sim'] for hard_prompt in hard_prompts]

# %%
counts, bins = np.histogram(similarities)
plt.stairs(counts, bins)

# %%
counts, bins = np.histogram(similarities)
plt.stairs(counts, bins)

# %%
with open(Path("hard_prompts_xgaze_baseline.json"), 'w') as f:
    json.dump(hard_prompts[:10], f)
